# %% [markdown]
# # PYTHON MARK DOWN

# %% [markdown]
# - This is RAW content

# %%
import sys
sys.version
# Out:
# '3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 13:17:27) [MSC v.1929 64 bit (AMD64)]'

# %%
print ('hello')
# Out:
# hello

# %% [markdown]
# This is markdown

# %% [markdown]
# ![image.png](attachment:c471dc57-3922-442a-b461-0985cb4b88ad.png)
